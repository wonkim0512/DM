# %% [markdown]
# # Clustering
# FIRA 빅데이터 플랫폼 과정 <데이터마이닝> - 2017.08.14.월 14:00-18:00

# %% [markdown]
# ### 1. Data
# - 1-1. `BathSoap.xlsx`
# - 1-2. Data Load : `pd.read_xlsx`
# - 1-3. Join Table : `pd.merge`
# - 1-4. Delete Rows & Columns
#
# ### 2. Hierarchical Clustering
# - 2-1. `sklearn.cluster.AgglomerativeClustering`
# - 2-2. Clustering with Dendrogram : `scipy.cluster.hierarchy`
#
# ### 3. K-means
# - 3-1. `sklearn.cluster.KMeans`
#
# ### 4. Analysis
# - 4-1. Choose K : Using Silhouette Plot
# - 4-2. .groupby()
#
# ### 5. 실습 : 비누 판매 마케팅 전략 수립을 위한 데이터 분석
# - 5-1. More Preprocessing
# - 5-2. 비누 구매 고객 세분화
# - 5-3. 타겟 클러스터 선정 및 마케팅 기획

# %%
import pandas as pd

df = pd.read_csv('german.csv')

# %%
cols = ['NEW_CAR', ]

# %%
dummies_df = pd.get_dummies('german.csv', columns=)
# Out:
#      Unnamed: 0 CHK_ACCT  DURATION  HISTORY NEW_CAR  AMOUNT  SAV_ACCT  \
# 0             1        0         6        4     A43    1169         4
# 1             2      A12        48        2     A43    5951         0
# 2             3      A14        12        4     A46    2096         0
# 3             4        0        42        2     A42    7882         0
# 4             5        0        24        3     A40    4870         0
# 5             6      A14        36        2     A46    9055         4
# 6             7      A14        24        2     A42    2835         2
# 7             8      A12        36        2     A41    6948         0
# 8             9      A14        12        2     A43    3059         3
# 9            10      A12        30        4     A40    5234         0
# 10           11      A12        12        2     A40    1295         0
# 11           12        0        48        2     A49    4308         0
# 12           13      A12        12        2     A43    1567         0
# 13           14        0        24        4     A40    1199         0
# 14           15        0        15        2     A40    1403         0
# 15           16        0        24        2     A43    1282         1
# 16           17      A14        24        4     A43    2424         4
# 17           18        0        30        0     A49    8072         4
# 18           19      A12        24        2     A41   12579         0
# 19           20      A14        24        2     A43    3430         2
# 20           21      A14         9        4     A40    2134         0
# 21           22        0         6        2     A43    2647         2
# 22           23        0        10        4     A40    2241         0
# 23           24      A12        12        4     A41    1804         1
# 24           25      A14        10        4     A42    2069         4
# 25           26        0         6        2     A42    1374         0
# 26           27      A14         6        0     A43     426         0
# 27           28      A13        12        1     A43     409         3
# 28           29      A12         7        2     A43    2415         0
# 29           30        0        60        3     A49    6836         0
# ..          ...      ...       ...      ...     ...     ...       ...
# 970         971      A12        15        2     A45    1514         1
# 971         972      A14        24        2     A40    7393         0
# 972         973        0        24        1     A40    1193         0
# 973         974        0        60        2     A49    7297         0
# 974         975      A14        30        4     A43    2831         0
# 975         976      A13        24        2     A43    1258         2
# 976         977      A12         6        2     A43     753         0
# 977         978      A12        18        3     A49    2427         4
# 978         979      A14        24        3     A40    2538         0
# 979         980      A12        15        1     A40    1264         1
# 980         981      A12        30        4     A42    8386         0
# 981         982      A14        48        2     A49    4844         0
# 982         983      A13        21        2     A40    2923         1
# 983         984        0        36        2     A41    8229         0
# 984         985      A14        24        4     A42    2028         0
# 985         986        0        15        4     A42    1433         0
# 986         987      A13        42        0     A49    6289         0
# 987         988      A14        13        2     A43    1409         1
# 988         989        0        24        2     A41    6579         0
# 989         990      A12        24        4     A43    1743         0
# 990         991      A14        12        4     A46    3565         4
# 991         992      A14        15        1     A43    1569         1
# 992         993        0        18        2     A43    1936         4
# 993         994        0        36        2     A42    3959         0
# 994         995      A14        12        2     A40    2390         4
# 995         996      A14        12        2     A42    1736         0
# 996         997        0        30        2     A41    3857         0
# 997         998      A14        12        2     A43     804         0
# 998         999        0        45        2     A43    1845         0
# 999        1000      A12        45        4     A41    4576         1
#
#      EMPLOYMENT  INSTALL_RATE MALE_DIV    ...    AGE  OTHER_INSTALL  RENT  \
# 0             4             4      A93    ...     67              0  A152
# 1             2             2      A92    ...     22              0  A152
# 2             3             2      A93    ...     49              0  A152
# 3             3             2      A93    ...     45              0  A153
# 4             2             3      A93    ...     53              0  A153
# 5             2             2      A93    ...     35              0  A153
# 6             4             3      A93    ...     53              0  A152
# 7             2             2      A93    ...     35              0  A151
# 8             3             2      A91    ...     61              0  A152
# 9             0             4      A94    ...     28              0  A152
# 10            1             3      A92    ...     25              0  A151
# 11            1             3      A92    ...     24              0  A151
# 12            2             1      A92    ...     22              0  A152
# 13            4             4      A93    ...     60              0  A152
# 14            2             2      A92    ...     28              0  A151
# 15            2             4      A92    ...     32              0  A152
# 16            4             4      A93    ...     53              0  A152
# 17            1             2      A93    ...     25              1  A152
# 18            4             4      A92    ...     44              0  A153
# 19            4             3      A93    ...     31              0  A152
# 20            2             4      A93    ...     48              0  A152
# 21            2             2      A93    ...     44              0  A151
# 22            1             1      A93    ...     48              0  A151
# 23            1             3      A93    ...     44              0  A152
# 24            2             2      A94    ...     26              0  A152
# 25            2             1      A93    ...     36              1  A152
# 26            4             4      A94    ...     39              0  A152
# 27            2             3      A92    ...     42              0  A151
# 28            2             3      A93    ...     34              0  A152
# 29            4             3      A93    ...     63              0  A152
# ..          ...           ...      ...    ...     ..            ...   ...
# 970           2             4      A93    ...     22              0  A152
# 971           2             1      A93    ...     43              0  A152
# 972           0             1      A92    ...     29              0  A151
# 973           4             4      A93    ...     36              0  A151
# 974           2             4      A92    ...     33              0  A152
# 975           2             3      A92    ...     57              0  A152
# 976           2             2      A92    ...     64              0  A152
# 977           4             4      A93    ...     42              0  A152
# 978           4             4      A93    ...     47              0  A152
# 979           2             2      A94    ...     25              0  A151
# 980           3             2      A93    ...     49              0  A152
# 981           0             3      A93    ...     33              1  A151
# 982           2             1      A92    ...     28              1  A152
# 983           2             2      A93    ...     26              0  A152
# 984           3             2      A93    ...     30              0  A152
# 985           2             4      A92    ...     25              0  A151
# 986           1             2      A91    ...     33              0  A152
# 987           0             2      A92    ...     64              0  A152
# 988           0             4      A93    ...     29              0  A153
# 989           4             4      A93    ...     48              0  A152
# 990           1             2      A93    ...     37              0  A152
# 991           4             4      A93    ...     34              1  A152
# 992           3             2      A94    ...     23              0  A151
# 993           0             4      A93    ...     30              0  A152
# %% [markdown]
# #### 1-1.  `BathSoap.xlsx`
# ---
# - sheet3 : DM_Sheet, 멤버 정보 및 비누 구입 정보
# - sheet4 : Durables, 멤버들의 비누 이외 타물품 소유 정보
# ---
# 비누를 구매한 고객들의 데이터를 토대로 군집화를 이용하여 효과적인 마케팅 전략을 수립하려고 한다. 총 600개의 표본을 각종 변수를 고려하여 치밀하게 표집하였다. 주어진 데이터는 각종 인구통계자료, 내구재 소유 자료, 제품의 카테고리와 각 브랜드에 대한 구매 데이터이다.

# %% [markdown]
# *Q. 군집화는 마케팅 전략을 세우는데 어떤 역할을 할 수 있는가?*

# %% [markdown]
# #### 1-2. Data Load : `pd.read_excel`
# ---
# `BathSoap.xlsx` 파일에서 데이터가 있는 sheet를 DataFrame으로 변환
# * pd.read_excel document 참고
# * sheet 위치, header로 쓸 row를 잘 지정할 것
# * row의 시작은 0

# %%
import pandas as pd

# %%
# df
df = pd.read_excel('BathSoap.xlsx', 2, header=2)

# %%
# durable_df
durable_df = pd.read_excel('BathSoap.xlsx', 3, header=4)

# %% [markdown]
# #### 1-3. Join Table : `pd.merge`
# ---
# DM_Sheet와 Durables의 DataFrame을 통합
# * 'Member id', 'MEM'을 기준으로 통합, Inner Join

# %%
# merged_df & set_index
merged_df = df.merge(durable_df, how="inner", left_on='Member id', right_on='MEM').set_index('Member id')

# %% [markdown]
# #### 1-4. Delete Rows & Columns
# ---
# * Delete Rows : 결측치가 있는 행은 지울 것
# * Delete Columns : 겹치거나 문제가 있는 열을 지울 것

# %%
# Delete Rows : no_nan_df 
no_nan_df = merged_df[merged_df.isnull().sum(axis=1) == 0]

# %%
# Delete columns : X_df
X_df = no_nan_df.drop(['MEM', 'Unnamed: 1'], axis=1)

# %% [markdown]
# ### 2. Hierarchical Clustering
# ---
#
#
# #### 2-1. `sklearn.cluster.AgglomerativeClustering`
# ---
# - Parameter
#     - `n_cluster` - 클러스터의 개수
# - Return : 모든 데이터의 Label

# %%
# import packages
from sklearn.cluster import AgglomerativeClustering

# %%
# parameter setting
n_clusters = 5

# %%
# sklearn_hc_model
sklearn_hc_model = AgglomerativeClustering(n_clusters=n_clusters)

# %%
# fit to model
sklearn_model.fit(X_df)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward',
#             memory=Memory(cachedir=None), n_clusters=5,
#             pooling_func=<function mean at 0x7f8aa405b0d0>)

# %%
# get predicted labels
predicted_labels_sklearn = sklearn_model.labels_
#sklearn_model.fit_predict(X_df)

# %%
# add result column to copied df
result_df = preprocessed_df.copy()
result_df['sklearn_labels'] = predicted_labels_sklearn

# %% [markdown]
# #### 2-2. Clustering with Dendrogram : `scipy.cluster.hierarchy`
# ---
# - Linkage Matrix
# - Dendromgram & Set k
# - get predicted_labels

# %% [markdown]
# ##### Linkage Matrix : `scipy.cluster.hierarchy.linkage`

# %%
# import packages
from scipy.cluster.hierarchy import linkage

# %%
# Z = linkage(X, method)
Z = linkage(preprocessed_df, 'centroid')

# %%
# What is Z, linkage?
Z[:10]
# Out:
# array([[ 1038.,  1039.,     0.,     2.],
#        [   64.,    65.,     0.,     2.],
#        [ 1070.,  1071.,     0.,     2.],
#        [ 1072.,  1073.,     0.,     2.],
#        [  268.,   269.,     0.,     2.],
#        [ 1096.,  1097.,     0.,     2.],
#        [  274.,   275.,     0.,     2.],
#        [ 1104.,  1105.,     0.,     2.],
#        [ 1108.,  1109.,     0.,     2.],
#        [ 1110.,  1111.,     0.,     2.]])

# %% [markdown]
# ##### Dendrogram & Set k : `scipy.cluster.hierarchy.dendrogram`

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# %%
def plot_dendrogram(title, xlabel, ylabel, Z, max_d=None, p=None):
    # Settings for figure
    plt.figure(figsize=(25, 10))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('Index of Data')
    plt.ylabel('Distance')

    # Dendrogram
    if p:
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            truncate_mode = 'lastp',
            p=p,
            show_contracted = True
        )
    else:
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
        )
    
    if max_d:
        plt.axhline(y=max_d, c='k')
    plt.show()

# %%
# plot dendrogram
plot_dendrogram('Hierarhcical Clustering Dendrogram', 'Index of Data', 'Distance', 
                Z)

# %%
# Dendrogram에 표현할 가지의 개수 정하기 - set p
plot_dendrogram('Hierarhcical Clustering Dendrogram', 'Index of Data', 'Distance', 
                Z, p=6)

# %%
# k를 결정하기 위해, k보다 큰 개수의 p를 가진 dendrogram을 그리고, max_distance를 결정한다.
plot_dendrogram('Hierarhcical Clustering Dendrogram', 'Index of Data', 'Distance', 
                Z, p=6)
max_d = 45000

# %%
# max_distance에 해당하는 선을 Dendrogram에 그려서 원하는 k를 표현하기 위한 max_distance를 확정한다.
plot_dendrogram('Hierarhcical Clustering Dendrogram', 'Index of Data', 'Distance', 
                Z, p=6, max_d=max_d)

# %% [markdown]
# ##### predicted_labels : `scipy.cluster.hierarchy.fcluster`

# %%
# import packages
from scipy.cluster.hierarchy import fcluster

# %%
# predicted_labels
predicted_labels_scipy = fcluster(Z, max_d, criterion='distance')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-82c447172bbf> in <module>()
#       1 # predicted_labels
# ----> 2 predicted_labels_scipy = fcluster(Z, max_d, criterion='distance')
#
# NameError: name 'Z' is not defined

# %%
# save to result_df
result_df['scipy_labels'] = predicted_labels_scipy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b62c5c59132a> in <module>()
#       1 # save to result_df
# ----> 2 result_df['scipy_labels'] = predicted_labels_scipy
#
# NameError: name 'predicted_labels_scipy' is not defined

# %% [markdown]
# ### 3. K-Means
# ---
# ##### 3-1. `sklearn.cluster.KMeans`
# ---
# - Parameter
#     - `n_cluster` - 클러스터의 개수
# - Return : 모든 데이터의 Label

# %%
from sklearn.cluster import KMeans

# %%
# set parameters
n_clusters = 5

# %%
# kmeans_model
kmeans_model = KMeans(n_clusters=n_clusters)

# %%
kmeans_model.fit(preprocessed_df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00],
#        [  1.07750300e+06,   3.04444444e+00,   2.34444444e+00,
#           8.85555556e+00,   1.83333333e+00,   3.55555556e+00,
#           3.53333333e+00,   4.65555556e+00,   3.11111111e+00,
#           9.88888889e-01,   1.50666667e+01,   3.45555556e+00,
#           1.42888889e+01,   1.47291111e+04,   3.31000000e+01,
#           1.50028333e+03,   3.62735023e+00,   4.70238594e+02,
#           1.05547166e+01,   9.21350611e-01,   3.89276601e-02,
#           3.97217293e-02,   1.95020729e-01,   1.98476989e-01,
#           1.70067770e-02,   3.84174991e-02,   8.51419741e-03,
#           2.11248341e-02,   3.63649993e-02,   1.45605036e-02,
#           4.70513471e-01,   2.01705238e-01,   4.85638964e-01,
#           2.20163027e-01,   9.24927713e-02,   4.61818558e-01,
#           9.56408246e-02,   8.85798474e-02,   3.54737795e-02,
#           3.79975801e-02,   2.01645918e-02,   2.13869729e-02,
#           3.40228454e-03,   1.24195049e-02,   2.15565062e-01,
#           7.55099429e-03,   1.07750300e+06,   1.19222222e+01,
#           0.00000000e+00,   2.77777778e-01,   2.00000000e-01,
#           3.88888889e-01,   2.22222222e-02,  -1.38777878e-16,
#           0.00000000e+00,   1.44444444e-01,   0.00000000e+00,
#          -3.46944695e-17,   2.22222222e-02,   2.22222222e-02,
#           3.66666667e-01,   6.66666667e-01,   0.00000000e+00,
#           1.11111111e-01,  -1.73472348e-18,   2.22222222e-02,
#           2.33333333e-01,   3.33333333e-02,  -3.46944695e-17,
#           0.00000000e+00,   3.33333333e-02,   8.11111111e-01,
#           2.11111111e+00,   7.77777778e-01,   3.33333333e-01,
#           1.11111111e-02,   8.61111111e-01,   2.22222222e-01,
#          -6.93889390e-18,   1.11111111e-02,   1.11111111e-01,
#          -3.46944695e-18,   0.00000000e+00,  -3.46944695e-18,
#           0.00000000e+00,   3.11111111e-01,   1.26666667e+00,
#           3.00000000e-01,   2.44444444e-01,  -3.46944695e-18,
#           0.00000000e+00,   6.55555556e-01,   1.66666667e-01,
#           1.55555556e-01,   6.66666667e-02,   3.88888889e-01,
#          -1.11022302e-16,   1.11111111e-02,   3.88888889e-02,
#          -6.93889390e-18,   3.33333333e-01,   4.44444444e-02,
#           0.00000000e+00,   0.00000000e+00,   3.33333333e-02,
#           2.22222222e-02,   6.66666667e-02,   2.22222222e-02,
#          -6.93889390e-18,  -1.73472348e-18,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00]])

# %%
# add result to result_df
result_df['kmeans_labels'] = predicted_labels_kmeans

# %% [markdown]
# ### 4. Analysis
# ---
# #### 4-1. Choose k : Using Silhouette Plot
# ---

# %%
# import packages
from sklearn.metrics import silhouette_score, silhouette_samples
import matplotlib.cm as cm

# %%
# silhouette_avg
silhoutette_avg = silhouette_score(X_df, result_df['kmeans_labels'])

# %%
# silhouette_value of each data
sample_silhouette_values = silhouette_samples(X_df, result_df['kmeans_labels'])

# %%
def plot_silhouette(X_df, labels):
    cluster_labels = sorted(np.unique(labels))
    n_clusters = len(cluster_labels)
    
    plt.figure()

    # axis setting
    ax = plt.gca()
    ax.set_xlim([-0.5, 1])
    ax.set_ylim([0, X_df.shape[0] + (n_clusters + 1) * 10])

    y_lower = 10
    
    silhouette_avg = silhouette_score(X_df, labels)
    print("k : {}".format(n_clusters))
    print("silhouette_avg : {}".format(silhouette_avg))
    data_silhouette_values = silhouette_samples(X_df, labels)

    for i in cluster_labels:
        # 특정 클러스터의 silhouette 값만 추출
        ith_cluster_silhouette_values = data_silhouette_values[labels == i]
        
        # 내림차순으로 정렬
        ith_cluster_silhouette_values.sort()

        # 해당 클러스터의 크기
        size_cluster_i = len(ith_cluster_silhouette_values)
       
        # 클러스터의 silhouette을 표시할 y축 최고값 결정
        y_upper = y_lower + size_cluster_i

        # 색
        color = cm.spectral(float(i) / n_clusters)
        
        # plot silhouette
        ax.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # y축에 클러스터 이름 표시
        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # 다음 클러스터의 silhouette을 표시할 최저점 조정
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax.set_title("The silhouette plot for k={}".format(n_clusters))
    ax.set_xlabel("The silhouette coefficient values")
    ax.set_ylabel("Cluster label")

    # silhouette 평균 값을 나타내는 선
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")

    # y축 값 제거
    ax.set_yticks([])

    plt.show()

# %%
# plot silhouette for choosing k
k_candidates = [2, 3, 4, 5]
for i in k_candidates:
    ith_model = KMeans(n_clusters=i)
    labels = ith_model.fit_predict(preprocessed_df)
    plot_silhouette(preprocessed_df, labels)
# Out:
# k : 2
# silhouette_avg : 0.6440512333889737
# k : 3
# silhouette_avg : 0.5996487526087213
# k : 4
# silhouette_avg : 0.6334000582083456
# k : 5
# silhouette_avg : 0.5959177149004259

# %% [markdown]
# #### 4-2. groupby()

# %%
result_df.groupby('scipy_labels').mean()
# Out:
#                    SEC       FEH        MT       SEX       AGE       EDU  \
# scipy_labels
# 1             3.527473  2.153846  8.615385  1.659341  3.208791  2.472527
# 2             3.170886  2.430380  9.056962  1.841772  3.259494  3.677215
# 3             2.417323  2.212598  8.881890  1.818898  3.165354  4.433071
# 4             1.656250  1.642857  6.982143  1.651786  3.209821  4.718750
#
#                     HS     CHILD        CS  Affluence Index      ...        \
# scipy_labels                                                     ...
# 1             4.406593  3.373626  0.835165        10.186813      ...
# 2             4.746835  3.000000  1.012658        14.493671      ...
# 3             4.314961  3.228346  1.007874        18.393701      ...
# 4             3.642857  3.343750  0.870536        20.799107      ...
#
#               Fax Machine  Video camera/Handycam  Radio Clock  Deep Freezer  \
# scipy_labels
# 1                0.000000               0.000000          0.0           0.0
# 2                0.000000               0.000000          0.0           0.0
# 3                0.000000               0.007874          0.0           0.0
# 4                0.026786               0.035714          0.0           0.0
#
#               Electirc Kettle\t\t  Dish Washing Machine  Kitchen Sink  \
# scipy_labels
# 1                             0.0                   0.0           0.0
# 2                             0.0                   0.0           0.0
# 3                             0.0                   0.0           0.0
# 4                             0.0                   0.0           0.0
#
#               Floor Polisher  sklearn_labels  kmeans_labels
# scipy_labels
# 1                        0.0        2.021978       2.373626
# 2                        0.0        1.924051       2.278481
# 3                        0.0        2.244094       2.000000
# 4                        0.0        2.370536       1.004464
#
# [4 rows x 115 columns]

# %% [markdown]
# *Q. 지금까지 진행해온 분석의 문제점은?*
# - 범주형 변수를 수치형 변수처럼 분석함
# - 수치형 데이터가 동일한 범위를 갖지 않음
# - 구매와 관련된 변수만 선택되지 않았음

# %%
# Hint 1
result_df.groupby('sklearn_labels').mean().iloc[:, :10]
# Out:
#                      SEC       FEH         MT       SEX       AGE       EDU  \
# sklearn_labels
# 0               2.795455  2.522727  10.159091  2.000000  3.500000  4.022727
# 1               2.873786  2.582524   9.495146  1.912621  3.320388  3.844660
# 2               2.290043  2.051948   8.311688  1.848485  3.194805  4.714286
# 3               2.664430  2.201342   8.986577  1.892617  3.241611  4.241611
# 4               2.123288  0.684932   3.054795  0.671233  2.890411  1.808219
#
#                       HS     CHILD        CS  Affluence Index
# sklearn_labels
# 0               6.522727  3.068182  1.068182        18.363636
# 1               5.543689  2.873786  1.019417        17.854369
# 2               3.744589  3.168831  1.008658        19.307359
# 3               4.778523  3.107383  1.006711        17.328859
# 4               1.095890  4.301370  0.328767         7.164384

# %%
# Hint 2 
X_df.iloc[:10, 11:46]
# Out:
#            Brand Runs  Total Volume  No. of  Trans   Value  \
# Member id
# 1010010.0        17.0        8025.0           24.0   818.0
# 1010010.0        17.0        8025.0           24.0   818.0
# 1010020.0        25.0       13975.0           40.0  1681.5
# 1010020.0        25.0       13975.0           40.0  1681.5
# 1014020.0        37.0       23100.0           63.0  1950.0
# 1014020.0        37.0       23100.0           63.0  1950.0
# 1014030.0         4.0        1500.0            4.0   114.0
# 1014030.0         4.0        1500.0            4.0   114.0
# 1014190.0         6.0        8300.0           13.0   591.0
# 1014190.0         6.0        8300.0           13.0   591.0
#
#            Trans / Brand Runs    Vol/Tran  Avg. Price   Pur Vol No Promo - %  \
# Member id
# 1010010.0            1.411765  334.375000    10.193146              1.000000
# 1010010.0            1.411765  334.375000    10.193146              1.000000
# 1010020.0            1.600000  349.375000    12.032200              0.887299
# 1010020.0            1.600000  349.375000    12.032200              0.887299
# 1014020.0            1.702703  366.666667     8.441558              0.941558
# 1014020.0            1.702703  366.666667     8.441558              0.941558
# 1014030.0            1.000000  375.000000     7.600000              1.000000
# 1014030.0            1.000000  375.000000     7.600000              1.000000
# 1014190.0            2.166667  638.461538     7.120482              0.614458
# 1014190.0            2.166667  638.461538     7.120482              0.614458
#
#            Pur Vol Promo 6 %  Pur Vol Other Promo %            ...             \
# Member id                                                      ...
# 1010010.0           0.000000               0.000000            ...
# 1010010.0           0.000000               0.000000            ...
# 1010020.0           0.096601               0.016100            ...
# 1010020.0           0.096601               0.016100            ...
# 1014020.0           0.019481               0.038961            ...
# 1014020.0           0.019481               0.038961            ...
# 1014030.0           0.000000               0.000000            ...
# 1014030.0           0.000000               0.000000            ...
# 1014190.0           0.144578               0.240964            ...
# 1014190.0           0.144578               0.240964            ...
#
#            PropCat 7  PropCat 8  PropCat 9  PropCat 10  PropCat 11  \
# Member id
# 1010010.0   0.000000   0.000000   0.000000         0.0    0.000000
# 1010010.0   0.000000   0.000000   0.000000         0.0    0.000000
# 1010020.0   0.026834   0.016100   0.014311         0.0    0.059034
# 1010020.0   0.026834   0.016100   0.014311         0.0    0.059034
# 1014020.0   0.033550   0.010823   0.008658         0.0    0.000000
# 1014020.0   0.033550   0.010823   0.008658         0.0    0.000000
# 1014030.0   0.000000   0.000000   0.000000         0.0    0.000000
# 1014030.0   0.000000   0.000000   0.000000         0.0    0.000000
# 1014190.0   0.000000   0.048193   0.000000         0.0    0.000000
# 1014190.0   0.000000   0.048193   0.000000         0.0    0.000000
#
#            PropCat 12  PropCat 13  PropCat 14  PropCat 15  \
# Member id
# 1010010.0    0.028037         0.0    0.130841    0.339564
# 1010010.0    0.028037         0.0    0.130841    0.339564
# 1010020.0    0.000000         0.0    0.080501    0.000000
# 1010020.0    0.000000         0.0    0.080501    0.000000
# 1014020.0    0.016234         0.0    0.561688    0.003247
# 1014020.0    0.016234         0.0    0.561688    0.003247
# 1014030.0    0.000000         0.0    0.600000    0.000000
# 1014030.0    0.000000         0.0    0.600000    0.000000
# 1014190.0    0.000000         0.0    0.144578    0.000000
# 1014190.0    0.000000         0.0    0.144578    0.000000
#
#            Radio/Transistor with FM
# Member id
# 1010010.0                       0.0
# 1010010.0                       0.0
# 1010020.0                       0.0
# 1010020.0                       0.0
# 1014020.0                       0.0
# 1014020.0                       0.0
# 1014030.0                       0.0
# 1014030.0                       0.0
# 1014190.0                       0.0
# 1014190.0                       0.0
#
# [10 rows x 35 columns]

# %%
# Hint 3 : 현재 변수의 개수
X_df.columns
# Out:
# Index(['SEC', 'FEH', 'MT', 'SEX', 'AGE', 'EDU', 'HS', 'CHILD', 'CS',
#        'Affluence Index',
#        ...
#        'Personal/Home Computers', 'Computer Printers', 'Fax Machine',
#        'Video camera/Handycam', 'Radio Clock', 'Deep Freezer',
#        'Electirc Kettle\t\t', 'Dish Washing Machine', 'Kitchen Sink',
#        'Floor Polisher'],
#       dtype='object', length=113)

# %% [markdown]
# ### 5. 실습 : 비누 판매 마케팅 전략 수립을 위한 데이터 분석
# ---
# #### 5-1. More Preprocessing
# ---
# ##### 1. ???

# %%
list(X_df.columns)
# Out:
# ['SEC',
#  'FEH',
#  'MT',
#  'SEX',
#  'AGE',
#  'EDU',
#  'HS',
#  'CHILD',
#  'CS',
#  'Affluence Index',
#  'No. of Brands',
#  'Brand Runs',
#  'Total Volume',
#  'No. of  Trans',
#  'Value',
#  'Trans / Brand Runs',
#  'Vol/Tran',
#  'Avg. Price ',
#  'Pur Vol No Promo - %',
#  'Pur Vol Promo 6 %',
#  'Pur Vol Other Promo %',
#  'Br. Cd. 57, 144',
#  'Br. Cd. 55',
#  'Br. Cd. 272',
#  'Br. Cd. 286',
#  'Br. Cd. 24',
#  'Br. Cd. 481',
#  'Br. Cd. 352',
#  'Br. Cd. 5',
#  'Others 999',
#  'Pr Cat 1',
#  'Pr Cat 2',
#  'Pr Cat 3',
#  'Pr Cat 4',
#  'PropCat 5',
#  'PropCat 6',
#  'PropCat 7',
#  'PropCat 8',
#  'PropCat 9',
#  'PropCat 10',
#  'PropCat 11',
#  'PropCat 12',
#  'PropCat 13',
#  'PropCat 14',
#  'PropCat 15',
#  'Radio/Transistor with FM',
#  'Radio/Transistor without FM',
#  'Stereo/Mono Tape Recorder',
#  'Two-in-one',
#  'Hi-Fi System/Music System without Compact disk',
#  'Hi-Fi System/Music System with Comapct disk',
#  'Walkman with FM',
#  'Walkman without FM',
#  'Discman with FM',
#  'Discman without FM',
#  'Video (VCP/VCR)',
#  'Laser Discs VCD/LD/DVD',
#  'TV - Black & White',
#  'Colour TV with remote',
#  'Colour TV without remote',
#  'Bicycle',
#  'Moped',
#  'Motorcycle',
#  'Scooter',
#  'Cars/Jeeps/Vans',
#  'Auto Rickshaw',
#  'Tractors',
#  'Electric/Immersion Water heater',
#  'LPG/Bio-Gas stove',
#  'Mixer/Grinder',
#  'Pressure Cooker',
#  'Toaster',
#  'Cooking Range',
#  'Refrigerator - Non Frost free\t\t',
#  'Refrigerator - Frost free',
#  'Automatic dish washer',
#  'Oven - Electric',
#  'Electric Pressure Cooker',
#  'Microwave Oven',
#  'Oven-In Built Range',
#  'Oven Ordinary Box (Gas)',
#  'Rice Cooker',
#  'Electric Table Fan',
#  'Electric Ceiling Fan',
#  'Torch',
#  'Sewing Machine',
#  'Generator',
#  'Pump Set/Water Pump',
#  'Electric Irons',
#  'Geyser',
#  'Cameras (still)',
#  'Telephones (with NSD/STD/ISD)',
#  'Telephones (Local only)',
#  'Air Coolers\t\t',
#  'Vacuum cleaner',
#  'Air Conditioners',
#  'Water purifier (Aquaguard etc.)',
#  'Washing Machines (Rs.5000+) Semi Automatic',
#  'Washing Machines (Rs.5000+) Fully Automatic',
#  'Washing Machines (Rs.5000+) Front Loading',
#  'Washing Machines (Rs.5000+) Top Loading',
#  'Mobil/Cellular phone',
#  'Pager',
#  'Personal/Home Computers',
#  'Computer Printers',
#  'Fax Machine',
#  'Video camera/Handycam',
#  'Radio Clock',
#  'Deep Freezer',
#  'Electirc Kettle\t\t',
#  'Dish Washing Machine',
#  'Kitchen Sink',
#  'Floor Polisher']

# %%
# dummify needed cols =
# dummified_df
dummy_needed_cols = ['FEH','MT', 'SEX', 'CHILD', 'CS']
dummified_df = pd.get_dummies(X_df, columns=dummy_needed_cols)

# %%
list(dummified_df.columns)
# Out:
# ['SEC',
#  'AGE',
#  'EDU',
#  'HS',
#  'Affluence Index',
#  'No. of Brands',
#  'Brand Runs',
#  'Total Volume',
#  'No. of  Trans',
#  'Value',
#  'Trans / Brand Runs',
#  'Vol/Tran',
#  'Avg. Price ',
#  'Pur Vol No Promo - %',
#  'Pur Vol Promo 6 %',
#  'Pur Vol Other Promo %',
#  'Br. Cd. 57, 144',
#  'Br. Cd. 55',
#  'Br. Cd. 272',
#  'Br. Cd. 286',
#  'Br. Cd. 24',
#  'Br. Cd. 481',
#  'Br. Cd. 352',
#  'Br. Cd. 5',
#  'Others 999',
#  'Pr Cat 1',
#  'Pr Cat 2',
#  'Pr Cat 3',
#  'Pr Cat 4',
#  'PropCat 5',
#  'PropCat 6',
#  'PropCat 7',
#  'PropCat 8',
#  'PropCat 9',
#  'PropCat 10',
#  'PropCat 11',
#  'PropCat 12',
#  'PropCat 13',
#  'PropCat 14',
#  'PropCat 15',
#  'Radio/Transistor with FM',
#  'Radio/Transistor without FM',
#  'Stereo/Mono Tape Recorder',
#  'Two-in-one',
#  'Hi-Fi System/Music System without Compact disk',
#  'Hi-Fi System/Music System with Comapct disk',
#  'Walkman with FM',
#  'Walkman without FM',
#  'Discman with FM',
#  'Discman without FM',
#  'Video (VCP/VCR)',
#  'Laser Discs VCD/LD/DVD',
#  'TV - Black & White',
#  'Colour TV with remote',
#  'Colour TV without remote',
#  'Bicycle',
#  'Moped',
#  'Motorcycle',
#  'Scooter',
#  'Cars/Jeeps/Vans',
#  'Auto Rickshaw',
#  'Tractors',
#  'Electric/Immersion Water heater',
#  'LPG/Bio-Gas stove',
#  'Mixer/Grinder',
#  'Pressure Cooker',
#  'Toaster',
#  'Cooking Range',
#  'Refrigerator - Non Frost free\t\t',
#  'Refrigerator - Frost free',
#  'Automatic dish washer',
#  'Oven - Electric',
#  'Electric Pressure Cooker',
#  'Microwave Oven',
#  'Oven-In Built Range',
#  'Oven Ordinary Box (Gas)',
#  'Rice Cooker',
#  'Electric Table Fan',
#  'Electric Ceiling Fan',
#  'Torch',
#  'Sewing Machine',
#  'Generator',
#  'Pump Set/Water Pump',
#  'Electric Irons',
#  'Geyser',
#  'Cameras (still)',
#  'Telephones (with NSD/STD/ISD)',
#  'Telephones (Local only)',
#  'Air Coolers\t\t',
#  'Vacuum cleaner',
#  'Air Conditioners',
#  'Water purifier (Aquaguard etc.)',
#  'Washing Machines (Rs.5000+) Semi Automatic',
#  'Washing Machines (Rs.5000+) Fully Automatic',
#  'Washing Machines (Rs.5000+) Front Loading',
#  'Washing Machines (Rs.5000+) Top Loading',
#  'Mobil/Cellular phone',
#  'Pager',
#  'Personal/Home Computers',
#  'Computer Printers',
#  'Fax Machine',
#  'Video camera/Handycam',
#  'Radio Clock',
#  'Deep Freezer',
#  'Electirc Kettle\t\t',
#  'Dish Washing Machine',
#  'Kitchen Sink',
#  'Floor Polisher',
#  'FEH_0.0',
#  'FEH_1.0',
#  'FEH_2.0',
#  'FEH_3.0',
#  'MT_0.0',
#  'MT_3.0',
#  'MT_4.0',
#  'MT_5.0',
#  'MT_6.0',
#  'MT_8.0',
#  'MT_9.0',
#  'MT_10.0',
#  'MT_12.0',
#  'MT_13.0',
#  'MT_14.0',
#  'MT_15.0',
#  'MT_16.0',
#  'MT_17.0',
#  'MT_19.0',
#  'SEX_0.0',
#  'SEX_1.0',
#  'SEX_2.0',
#  'CHILD_1.0',
#  'CHILD_2.0',
#  'CHILD_3.0',
#  'CHILD_4.0',
#  'CHILD_5.0',
#  'CS_0.0',
#  'CS_1.0',
#  'CS_2.0']

# %% [markdown]
# ##### 2. ???

# %%
# scale needed cols = 
# scaled_df 
scale_needed_cols = dummified_df.columns[4:13]
scaled_df = dummified_df.copy()
scaled_df[scale_needed_cols] = (X_df[scale_needed_cols] - X_df[scale_needed_cols].mean())/ X_df[scale_needed_cols].std()

# %%
scaled_df[scale_needed_cols]
# Out:
#            Affluence Index  No. of Brands  Brand Runs  Total Volume  \
# Member id
# 1010010.0        -1.316929      -0.403196    0.120123     -0.500799
# 1010010.0        -1.316929      -0.403196    0.120123     -0.500799
# 1010020.0         0.173603       0.863388    0.889935      0.265250
# 1010020.0         0.173603       0.863388    0.889935      0.265250
# 1014020.0         0.524317       0.863388    2.044653      1.440072
# 1014020.0         0.524317       0.863388    2.044653      1.440072
# 1014030.0        -1.492286      -1.036488   -1.130822     -1.340877
# 1014030.0        -1.492286      -1.036488   -1.130822     -1.340877
# 1014190.0        -0.615502      -0.403196   -0.938369     -0.465393
# 1014190.0        -0.615502      -0.403196   -0.938369     -0.465393
# 1017020.0        -0.352467      -0.403196    0.986162      0.805990
# 1017020.0        -0.352467      -0.403196    0.986162      0.805990
# 1017110.0        -0.527824       0.230096    0.120123     -0.252959
# 1017110.0        -0.527824       0.230096    0.120123     -0.252959
# 1017160.0        -1.492286      -0.403196   -0.745916     -0.336645
# 1017160.0        -1.492286      -0.403196   -0.745916     -0.336645
# 1017360.0        -0.001754      -1.036488   -0.361010      1.876526
# 1017360.0        -0.001754      -1.036488   -0.361010      1.876526
# 1017460.0        -0.966216       0.230096   -0.264783     -0.574185
# 1017460.0        -0.966216       0.230096   -0.264783     -0.574185
# 1017490.0         1.138065       0.230096    0.793709      0.561369
# 1017490.0         1.138065       0.230096    0.793709      0.561369
# 1020070.0         0.085925       0.230096    0.505029      0.252375
# 1020070.0         0.085925       0.230096    0.505029      0.252375
# 1020210.0        -0.790859      -0.403196   -0.649689      1.127859
# 1020210.0        -0.790859      -0.403196   -0.649689      1.127859
# 1024050.0        -0.615502       0.230096   -0.553463      0.455152
# 1024050.0        -0.615502       0.230096   -0.553463      0.455152
# 1024100.0        -0.177110      -1.036488   -0.745916     -0.355958
# 1024100.0        -0.177110      -1.036488   -0.745916     -0.355958
# ...                    ...            ...         ...           ...
# 1165720.0         1.225744       1.496680    2.140880     -0.298021
# 1165720.0         1.225744       1.496680    2.140880     -0.298021
# 1166020.0         0.787352       0.230096    2.429560      1.309393
# 1166020.0         0.787352       0.230096    2.429560      1.309393
# 1166080.0         0.348960       1.496680    0.697482     -0.429987
# 1166080.0         0.348960       1.496680    0.697482     -0.429987
# 1166340.0         2.716276      -0.403196    0.120123     -0.808505
# 1166340.0         2.716276      -0.403196    0.120123     -0.808505
# 1166460.0         2.014849      -0.403196    1.755974      0.477683
# 1166460.0         2.014849      -0.403196    1.755974      0.477683
# 1166470.0         1.050387      -1.036488   -0.072330     -0.748638
# 1020210.0      -0.295829  0.227250            0.104151  1.528775    -1.174923
# 1024050.0      -0.181018 -0.070103            0.070011  0.549892    -0.956618
# 1024050.0      -0.181018 -0.070103            0.070011  0.549892    -0.956618
# 1024100.0      -0.353234 -0.476204            0.194837 -0.197263    -0.484526
# 1024100.0      -0.353234 -0.476204            0.194837 -0.197263    -0.484526
# ...                  ...       ...                 ...       ...          ...
# 1165720.0       0.967088 -0.172620           -0.520261 -0.864848     0.136100
# 1165720.0       0.967088 -0.172620           -0.520261 -0.864848     0.136100
# 1166020.0       1.713357  1.442719           -0.433978 -0.213151    -0.003226
# 1166020.0       1.713357  1.442719           -0.433978 -0.213151    -0.003226
# 1166080.0       0.278224 -0.380484           -0.404245 -0.711245    -0.041503
# 1166080.0       0.278224 -0.380484           -0.404245 -0.711245    -0.041503
# 1166340.0      -0.525450 -0.641815           -0.508370 -0.639090     0.492948
# 1166340.0      -0.525450 -0.641815           -0.508370 -0.639090     0.492948
# 1166460.0       1.024494  0.611261           -0.451887 -0.386770     0.047639
# 1166460.0       1.024494  0.611261           -0.451887 -0.386770     0.047639
# 1166470.0       0.048603 -0.641589           -0.186043 -0.902550     0.215110
# 1166470.0       0.048603 -0.641589           -0.186043 -0.902550     0.215110
# 1166740.0      -1.042098 -0.449583           -0.621335  0.473106     0.466869
# 1166740.0      -1.042098 -0.449583           -0.621335  0.473106     0.466869
# 1166870.0      -0.812477 -0.025359            0.082813  0.282490     1.097191
# 1166870.0      -0.812477 -0.025359            0.082813  0.282490     1.097191
# 1166960.0      -1.099503 -1.196083           -0.493308 -0.730794    -0.476049
# 1166960.0      -1.099503 -1.196083           -0.493308 -0.730794    -0.476049
# 1166980.0      -0.181018 -0.748636           -0.178164 -0.907936     0.248470
# 1166980.0      -0.181018 -0.748636           -0.178164 -0.907936     0.248470
# 1167090.0      -0.525450 -0.135238            0.684540 -0.019399     0.444047
# 1167090.0      -0.525450 -0.135238            0.684540 -0.019399     0.444047
# 1167230.0      -0.181018 -0.550967           -0.537839 -0.943843     1.340987
# 1167230.0      -0.181018 -0.550967           -0.537839 -0.943843     1.340987
# 1167340.0      -0.353234  2.226317           -0.500046  3.011970    -0.129614
# 1167340.0      -0.353234  2.226317           -0.500046  3.011970    -0.129614
# 1167350.0      -0.697666 -0.993882           -0.518913 -0.505021    -0.927757
# 1167350.0      -0.697666 -0.993882           -0.518913 -0.505021    -0.927757
# 1167670.0      -0.984693  0.053936           -0.407956  1.864092    -0.153536
# 1167670.0      -0.984693  0.053936           -0.407956  1.864092    -0.153536
#
# [1200 rows x 9 columns]

# %% [markdown]
# #### 5-2. 비누 구매 고객 세분화
# ---
# - 구매 행동(구매량, 빈도, 할인에 대한 민감성, 브랜드 충성도), 구매 기반(가격, 구매제의) 등의 변수를 이용하여 군집화하라
# - 어떤 군집화 방법을 선택할 것인가? 그 이유는 무엇인가?
# - k는 몇 개로 선택할 것인가? 한번에 진행 가능한 마케팅 전략이 2~5개라고 할 때 k의 개수는 타당한가?

# %% [markdown]
# ##### 변수 선택
# ---
# 구매행태에 관련있는 No. of Brands ~ PropCat 15까지를 구매 패턴과 관련된 군집화의 변수로 사용한다.

# %%
# Select Features
selected_feautures = scaled_df.columns[5:40]
selected_features_df = scaled_df[selected_feautures]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-52e2394a6cac> in <module>()
#       1 # Select Features
# ----> 2 selected_feautures = scaled_df.columns[5:40]
#       3 selected_features_df = scaled_df[selected_feautures]
#
# NameError: name 'scaled_df' is not defined

# %% [markdown]
# ##### 방법 선정
# ---
# AgglomerativeClustering을 사용한다. Dendrogram을 통해 클러스터의 거리 차를 토대로 k를 선정할 수 있으며,

# %%
# Choose Methods
Z = linkage(selected_features_df, 'ward')
plot_dendrogram('Bath Soap Member Clustering', "Index", 'Distance'
                , Z)

# %% [markdown]
# ##### k 선정
# ---
# Dendrogram 상으로 보았을 때 4개의 k를 선정하는 것이 가장 타당한 것으로 보인다. 수립할 수 있는 마케팅 전략의 개수와 유사하다.

# %%
plot_dendrogram('Bath Soap Member Clustering', "Index", 'Distance'
                , Z, p=10, max_d=40)

# %%
predicted_labels_bath_soap = fcluster(Z, 40, criterion='distance')

# %%
scaled_df['predicted_labels'] = predicted_labels_bath_soap

# %% [markdown]
# #### 5-3. 타겟 클러스터 선정 및 마케팅 기획
# ---
# * 분석된 세분화에서 두 개의 클러스터를 선정하고, 그 집단의 특성에 대해 분석하시오.
# * 선정한 두 클러스터에 대한 마케팅 전략을 수립하시오.

# %%
# Analysis
scaled_df.groupby('predicted_labels').mean().iloc[:, :40]
# Out:
#                        SEC       AGE       EDU        HS  Affluence Index  \
# predicted_labels
# 1                 3.189655  3.189655  2.775862  4.344828        -0.644224
# 2                 2.406040  3.127517  3.785235  3.479866        -0.132977
# 3                 2.158940  3.271523  5.112583  4.403974         0.487155
# 4                 2.924731  3.408602  3.924731  6.032258         0.036900
#
#                   No. of Brands  Brand Runs  Total Volume  No. of  Trans  \
# predicted_labels
# 1                     -0.730761   -0.996437      0.273197      -0.362142
# 2                     -0.418072   -0.405894     -0.520397      -0.541631
# 3                      0.930492    1.037780     -0.040492       0.905121
# 4                      0.284573    0.237043      1.562874       0.491797
#
#                      Value     ...      PropCat 6  PropCat 7  PropCat 8  \
# predicted_labels               ...
# 1                -0.382214     ...       0.043923   0.098081   0.002018
# 2                -0.473365     ...       0.081274   0.100349   0.092856
# 3                 0.250164     ...       0.124958   0.110284   0.113423
# 4                 1.348993     ...       0.104928   0.063440   0.034131
#
#                   PropCat 9  PropCat 10  PropCat 11  PropCat 12  PropCat 13  \
# predicted_labels
# 1                  0.021422    0.000846    0.004299    0.001376    0.002217
# 2                  0.023549    0.027082    0.032020    0.006832    0.022244
# 3                  0.045748    0.021899    0.028061    0.008641    0.048124
# 4                  0.035649    0.007770    0.038622    0.003331    0.010090
#
#                   PropCat 14  PropCat 15
# predicted_labels
# 1                   0.702295    0.003309
# 2                   0.076908    0.027764
# 3                   0.045350    0.029468
# 4                   0.122460    0.024984
#
# [4 rows x 40 columns]
