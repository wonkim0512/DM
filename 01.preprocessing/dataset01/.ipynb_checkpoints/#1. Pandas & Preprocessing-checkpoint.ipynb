# %% [markdown]
# # Pandas & Preprocessing
# 2017.08.11.금 09:00-13:00

# %% [markdown]
# ## 오늘의 주제
# ---
# ### 1. Pandas Tutorial
# - 1-1. Data Structure
# - 1-2. Selection : Slicing, Getting
# - 1.3. Add New Rows & Columns
# - 1-4. Inspection
# - 1-5. Arithmetic
# - 1-6. Map & Apply Function
# - 1-7. Sort
#
# ### 2. Preprocessing
# - 2-1. Data Load from .csv, .sql
# - 2-2. Join table
# - 2-3. Save DataFrame : pickle
#
# ### 실습 : 군집화 실습 데이터 기본 전처리
#
# ### 3. Basic Visualization
# - 3-1. scatter plot by matplotlib.pyplot
# - 3-2. heatmap using seaborn
# - 3-3. line plot w/ hover by bokeh.js

# %% [markdown]
# ### 1. Pandas Tutorial
# ---
# Pandas는 NumPy를 기반으로 하는 데이터 분석에 최적화된 파이썬 라이브러리입니다. Series, DataFrame의 데이터 구조를 제공하고 이를 계산하는 도구를 제공하여 데이터 분석을 보다 편리하게 해줍니다.

# %%
# import package
import pandas as pd
# version

# %% [markdown]
# #### 1.1. Data Structure
# ---
# ##### pd.Series
# 1. Labeling이 가능한 1차원 Array Object
# 2. 모두 같은 데이터형을 가집니다.

# %%
# pd.Series [3, -5, 7, 4]
s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])

# %% [markdown]
# ##### pd.DataFrame
# 1. Labeling이 가능한 2차원 Array Object
# 2. column 별로 서로 다른 데이터형을 가질 수 있습니다.

# %%
# pd.DataFrame
data = {'Country': ['Belgium', 'India', 'Brazil'],
        'Capital': ['Brussels', 'New Delhi', 'Brasília'],
        'Population': [11190846, 1303171035, 207847528]}

df= pd.DataFrame(data
                 , columns=['Country', 'Capital', 'Population']
                 , index=['Country 1', 'Country 2', 'Country 3'])

# %% [markdown]
# #### 1.2. Selection : getting, slicing
# ---
#
# ##### Getting

# %%
# Series : By index
print(s['b'])
# Out:
# -5

# %%
# DataFrame : By Row 
df[1:] # can not select just one value - getting 'subset'
# Out:
#           Country    Capital  Population
# Country 2   India  New Delhi  1303171035
# Country 3  Brazil   Brasília   207847528

# %%
# DataFrame : By column
df['Capital']
# Out:
# Country 1     Brussels
# Country 2    New Delhi
# Country 3     Brasília
# Name: Capital, dtype: object

# %% [markdown]
# ##### Slicing
# * df.iloc : index를 통한 slicing
# * df.loc : index, label을 통한 slicing

# %%
# By Position
df.iloc[0, 0]
# Out:
# 'Belgium'

# %%
# By Label
df.loc['Country 1', ['Capital']]
# Out:
# Capital    Brussels
# Name: Country 1, dtype: object

# %%
df.loc[:, 'Capital'] # (= df.Capital)
# Out:
# Country 1     Brussels
# Country 2    New Delhi
# Country 3     Brasília
# Name: Capital, dtype: object

# %% [markdown]
# ##### Boolean Slicing (Mask)
# 해당 조건을 만족하는 부분만 slicing - True/False 기반

# %%
s[s>1]
# Out:
# a    3
# c    7
# d    4
# dtype: int64

# %%
# Mask?
s>1
# Out:
# a     True
# b    False
# c     True
# d     True
# dtype: bool

# %%
# 부정 조건
s[~(s>1)]
# Out:
# b   -5
# dtype: int64

# %%
# OR
s[(s < -1) | (s > 5)]
# Out:
# b   -5
# c    7
# dtype: int64

# %%
df[df['Population']>1200000000] # 특정 열 조건으로 필터링 가능
# Out:
#           Country    Capital  Population
# Country 2   India  New Delhi  1303171035

# %%
df['Population']>1200000000
# Out:
# Country 1    False
# Country 2     True
# Country 3    False
# Name: Population, dtype: bool

# %% [markdown]
# #### 1.3. Adding a New Row & Column
# ---
# ##### Row

# %%
# adding new or update row
df.loc['Country 4'] = ['Korea', 'Seoul', 50000000, 'Asia']

# %% [markdown]
# *Q. .iloc으로 새로운 행을 추가할 수 있는가? 그 이유는?*

# %%
# Can't use iloc
df.iloc[df.shape[0]] = ['Korea', 'Seoul', 50000000, 'Asia']

# %% [markdown]
# ##### Column

# %%
# adding new or update columns
df['Continent'] = ['Europe', 'Asia', 'America']

# %% [markdown]
# #### 1.4. Inspection
# ---

# %%
# DataFrame 크기 정보
df.shape
# Out:
# (3, 3)

# %%
# 행 정보
df.index
# Out:
# Index(['Country 1', 'Country 2', 'Country 3'], dtype='object')

# %%
# 열 정보
df.columns
# Out:
# Index(['Country', 'Capital', 'Population'], dtype='object')

# %%
# 상세 정보 : 행 정보, 열 정보 및 데이터형, 메모리
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Country 1 to Country 3
# Data columns (total 3 columns):
# Country       3 non-null object
# Capital       3 non-null object
# Population    3 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 176.0+ bytes

# %% [markdown]
# #### 1.5 Arithmetic
# ---
# ##### 모든 타입 공통

# %%
df.count()
# Out:
# Country       3
# Capital       3
# Population    3
# dtype: int64

# %%
df.sum()
# Out:
# Country              BelgiumIndiaBrazil
# Capital       BrusselsNew DelhiBrasília
# Population                   1522209409
# dtype: object

# %%
df.cumsum()
# Out:
#                       Country                    Capital  Population
# Country 1             Belgium                   Brussels    11190846
# Country 2        BelgiumIndia          BrusselsNew Delhi  1314361881
# Country 3  BelgiumIndiaBrazil  BrusselsNew DelhiBrasília  1522209409

# %%
df.min()
# Out:
# Country        Belgium
# Capital       Brasília
# Population    11190846
# dtype: object

# %%
df.min(axis=1)
# Out:
# Country 1      11190846
# Country 2    1303171035
# Country 3     207847528
# dtype: int64

# %%
df.max()
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# dtype: object

# %% [markdown]
# ##### 수치형 데이터

# %%
df.min()['Population'] / df.max()['Population']
# Out:
# 0.008587396204673933

# %%
df['Population'].idxmin()
# Out:
# 'Country 1'

# %%
df['Population'].argmax()
# Out:
# 'Country 2'

# %%
df['Population'].idxmax()
# Out:
# 'Country 2'

# %%
df.describe()
# Out:
#          Population
# count  3.000000e+00
# mean   5.074031e+08
# std    6.961346e+08
# min    1.119085e+07
# 25%    1.095192e+08
# 50%    2.078475e+08
# 75%    7.555093e+08
# max    1.303171e+09

# %%
df.mean()
# Out:
# Population    5.074031e+08
# dtype: float64

# %% [markdown]
# #### 1.6 Map & Apply Function

# %% [markdown]
# #### 1-7. Sort

# %% [markdown]
# ### 2. Preprocessing
# ---
# - 2-1. Data from .csv, .sql to DataFrame
# - 2-2. Merge/Join two DataFrame : .merge()
# - 2-3. Fill or Abandon NaN values
# - 2-4. Save & Load as DataFrame : pickle
# - 2-5. Data Summary & Exploration : groupby

# %% [markdown]
# ##### 사용 데이터 : 2016 US Election (Kaggle) - 2016년 미 대선 정당별 대선 후보 경선 결과
# - primary_results : 24611 x 8 (공화당, 민주당 대통령 후보 경선 결과)
# - county_facts : 3195 x 54 (state, couty별 인구, 주거, 기업, 유통 등 특성 정보)
# - county_facts_dictionary : county_facts의 column에 대한 설명 (50개)

# %% [markdown]
# #### 2-1. Data from .csv, .sql to DataFrame
# ---
# ##### pd.read_sql & sqlite3

# %%
# import package
import sqlite3
# import sqlalchemy

# %%
# connect sqlite3
con = sqlite3.connect('database.sqlite')

# %%
# read_sql
sql_df = pd.read_sql('SELECT * FROM primary_results', con)
sql_df = pd.read_sql('SELECT * FROM county_facts_dictionary', con)

# %% [markdown]
# ##### pd.read_csv

# %%
# county_facts_df
county_facts_df = pd.read_csv('county_facts.csv')

# %% [markdown]
# *Q. `county_facts.csv`를 부른 DataFrame을 State와 County로 분리하여 각각 state_df, county_df로 나누어라*
# <br>
# - Hint : fips는 지역번호를 나타내며, 0은 미국 전체, 천의 자리 이상은 주를 나타낸다

# %%
# state_df
state_df = county_facts_df[county_facts_df['fips'] % 1000 == 0]

# county_df
county_df = county_facts_df[county_facts_df['fips'] % 1000 != 0]

# %%
primary_df = pd.read_csv('primary_results.csv')

# %% [markdown]
# #### 2-2. Merge/Join two DataFrames : .merge()

# %%
# inner vs. outer
primary_couty_facts_inner_df = primary_df.merge(county_df, how="inner", left_on='fips', right_on='fips', suffixes=('_primary', '_county'))
primary_couty_facts_outer_df = primary_df.merge(county_df, how="outer", left_on='fips', right_on='fips', suffixes=('_primary', '_county'))

# %% [markdown]
# *Q. inner? outer?*

# %% [markdown]
# #### 2-3. Fill or Abandon NaN

# %%
# check NaN in data
primary_couty_facts_inner_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# *Q. 2-2의 DataFrame을 공화당과 민주당의 결과로 분리하여 각각 rep_df, dem_df로 나누어라*

# %%
rep_df = primary_couty_facts_inner_df[primary_couty_facts_inner_df['party'] == 'Republican']
dem_df = primary_couty_facts_inner_df[primary_couty_facts_inner_df['party'] == 'Democrat']

# %% [markdown]
# #### 2-4.

# %%
rep_df.groupby('candidate')['votes'].sum()
# Out:
# candidate
# Ben Carson          536822
# Carly Fiorina         3485
# Chris Christie        3284
# Donald Trump      12559572
# Jeb Bush             63101
# John Kasich        3823482
# Marco Rubio        3119282
# Mike Huckabee         3345
# Rand Paul             8479
# Rick Santorum         1782
# Ted Cruz           7359825
# Name: votes, dtype: int64

# %% [markdown]
# #### 2-4. Save & Load DataFrame : pickle

# %%
# import pickle
import pickle

# %%
# save as DataFrame
with open('save_df.pkl', 'wb') as f:
    pickle.dump(joined_df, f)

# %%
# load as DataFrame
with open('save_df.pkl', 'rb') as f:
    loaded_df =pickle.load(f)

# %%
loaded_df
# Out:
#          state state_abbreviation_primary   county     fips       party  \
# 0      Alabama                         AL  Autauga   1001.0    Democrat
# 1      Alabama                         AL  Autauga   1001.0    Democrat
# 2      Alabama                         AL  Autauga   1001.0  Republican
# 3      Alabama                         AL  Autauga   1001.0  Republican
# 4      Alabama                         AL  Autauga   1001.0  Republican
# 5      Alabama                         AL  Autauga   1001.0  Republican
# 6      Alabama                         AL  Autauga   1001.0  Republican
# 7      Alabama                         AL  Baldwin   1003.0    Democrat
# 8      Alabama                         AL  Baldwin   1003.0    Democrat
# 9      Alabama                         AL  Baldwin   1003.0  Republican
# 10     Alabama                         AL  Baldwin   1003.0  Republican
# 11     Alabama                         AL  Baldwin   1003.0  Republican
# 12     Alabama                         AL  Baldwin   1003.0  Republican
# 13     Alabama                         AL  Baldwin   1003.0  Republican
# 14     Alabama                         AL  Barbour   1005.0    Democrat
# 15     Alabama                         AL  Barbour   1005.0    Democrat
# 16     Alabama                         AL  Barbour   1005.0  Republican
# 17     Alabama                         AL  Barbour   1005.0  Republican
# 18     Alabama                         AL  Barbour   1005.0  Republican
# 19     Alabama                         AL  Barbour   1005.0  Republican
# 20     Alabama                         AL  Barbour   1005.0  Republican
# 21     Alabama                         AL     Bibb   1007.0    Democrat
# 22     Alabama                         AL     Bibb   1007.0    Democrat
# 23     Alabama                         AL     Bibb   1007.0  Republican
# 24     Alabama                         AL     Bibb   1007.0  Republican
# 25     Alabama                         AL     Bibb   1007.0  Republican
# 26     Alabama                         AL     Bibb   1007.0  Republican
# 27     Alabama                         AL     Bibb   1007.0  Republican
# 28     Alabama                         AL   Blount   1009.0    Democrat
# 29     Alabama                         AL   Blount   1009.0    Democrat
# ...        ...                        ...      ...      ...         ...
# 24978      NaN                        NaN      NaN  44003.0         NaN
# 24979      NaN                        NaN      NaN  44005.0         NaN
# 24980      NaN                        NaN      NaN  44007.0         NaN
# 24981      NaN                        NaN      NaN  44009.0         NaN
# 24982      NaN                        NaN      NaN  45000.0         NaN
# 24983      NaN                        NaN      NaN  46000.0         NaN
# 24984      NaN                        NaN      NaN  47000.0         NaN
# 24985      NaN                        NaN      NaN  48000.0         NaN
# 24986      NaN                        NaN      NaN  49000.0         NaN
# 24987      NaN                        NaN      NaN  50000.0         NaN
# 24988      NaN                        NaN      NaN  50001.0         NaN
# 24989      NaN                        NaN      NaN  50003.0         NaN
# 24990      NaN                        NaN      NaN  50005.0         NaN
# 24991      NaN                        NaN      NaN  50007.0         NaN
# 24992      NaN                        NaN      NaN  50009.0         NaN
# 24993      NaN                        NaN      NaN  50011.0         NaN
# 24994      NaN                        NaN      NaN  50013.0         NaN
# 24995      NaN                        NaN      NaN  50015.0         NaN
# 24996      NaN                        NaN      NaN  50017.0         NaN
# 24997      NaN                        NaN      NaN  50019.0         NaN
# 24998      NaN                        NaN      NaN  50021.0         NaN
# 24999      NaN                        NaN      NaN  50023.0         NaN
# 25000      NaN                        NaN      NaN  50025.0         NaN
# 25001      NaN                        NaN      NaN  50027.0         NaN
# 25002      NaN                        NaN      NaN  51000.0         NaN
# 25003      NaN                        NaN      NaN  51515.0         NaN
# 25004      NaN                        NaN      NaN  53000.0         NaN
# 25005      NaN                        NaN      NaN  54000.0         NaN
# 25006      NaN                        NaN      NaN  55000.0         NaN
# 25007      NaN                        NaN      NaN  56000.0         NaN
#
#              candidate    votes  fraction_votes          area_name  \
# 0       Bernie Sanders    544.0           0.182     Autauga County
# 1      Hillary Clinton   2387.0           0.800     Autauga County
# 2           Ben Carson   1764.0           0.146     Autauga County
# 3         Donald Trump   5387.0           0.445     Autauga County
# 4          John Kasich    421.0           0.035     Autauga County
# 5          Marco Rubio   1785.0           0.148     Autauga County
# 6             Ted Cruz   2482.0           0.205     Autauga County
# 7       Bernie Sanders   2694.0           0.329     Baldwin County
# 8      Hillary Clinton   5290.0           0.647     Baldwin County
# 9           Ben Carson   4221.0           0.084     Baldwin County
# 10        Donald Trump  23618.0           0.469     Baldwin County
# 11         John Kasich   2987.0           0.059     Baldwin County
# 12         Marco Rubio   9703.0           0.193     Baldwin County
# 13            Ted Cruz   8571.0           0.170     Baldwin County
# 14      Bernie Sanders    222.0           0.078     Barbour County
# 15     Hillary Clinton   2567.0           0.906     Barbour County
# 16          Ben Carson    417.0           0.122     Barbour County
# 17        Donald Trump   1710.0           0.501     Barbour County
# 18         John Kasich    123.0           0.036     Barbour County
# 19         Marco Rubio    498.0           0.146     Barbour County
# 20            Ted Cruz    609.0           0.179     Barbour County
# 21      Bernie Sanders    246.0           0.197        Bibb County
# 22     Hillary Clinton    942.0           0.755        Bibb County
# 23          Ben Carson    393.0           0.099        Bibb County
# 24        Donald Trump   1959.0           0.494        Bibb County
# 25         John Kasich     84.0           0.021        Bibb County
# 26         Marco Rubio    444.0           0.112        Bibb County
# 27            Ted Cruz   1011.0           0.255        Bibb County
# 28      Bernie Sanders    395.0           0.386      Blount County
# 29     Hillary Clinton    564.0           0.551      Blount County
# ...                ...      ...             ...                ...
# 24978              NaN      NaN             NaN        Kent County
# 24979              NaN      NaN             NaN     Newport County
# 24980              NaN      NaN             NaN  Providence County
# 24981              NaN      NaN             NaN  Washington County
# 24982              NaN      NaN             NaN     South Carolina
# 24983              NaN      NaN             NaN       South Dakota
# 24984              NaN      NaN             NaN          Tennessee
# 24985              NaN      NaN             NaN              Texas
# 24986              NaN      NaN             NaN               Utah
# 24987              NaN      NaN             NaN            Vermont
# 24988              NaN      NaN             NaN     Addison County
# 24989              NaN      NaN             NaN  Bennington County
# 24990              NaN      NaN             NaN   Caledonia County
# 24991              NaN      NaN             NaN  Chittenden County
# 24992              NaN      NaN             NaN       Essex County
# 24993              NaN      NaN             NaN    Franklin County
# 24994              NaN      NaN             NaN  Grand Isle County
# 24995              NaN      NaN             NaN    Lamoille County
# 24996              NaN      NaN             NaN      Orange County
# 24997              NaN      NaN             NaN     Orleans County
# 24998              NaN      NaN             NaN     Rutland County
# 24999              NaN      NaN             NaN  Washington County
# 25000              NaN      NaN             NaN     Windham County
# 25001              NaN      NaN             NaN     Windsor County
# 25002              NaN      NaN             NaN           Virginia
# 25003              NaN      NaN             NaN       Bedford city
# 25004              NaN      NaN             NaN         Washington
# 25005              NaN      NaN             NaN      West Virginia
# 25006              NaN      NaN             NaN          Wisconsin
# 25007              NaN      NaN             NaN            Wyoming
#
#       state_abbreviation_county    ...      SBO415207  SBO015207    MAN450207  \
# 0                            AL    ...            0.7       31.7          0.0
# 1                            AL    ...            0.7       31.7          0.0
# 2                            AL    ...            0.7       31.7          0.0
# 3                            AL    ...            0.7       31.7          0.0
# 4                            AL    ...            0.7       31.7          0.0
# 5                            AL    ...            0.7       31.7          0.0
# 6                            AL    ...            0.7       31.7          0.0
# 7                            AL    ...            1.3       27.3    1410273.0
# 8                            AL    ...            1.3       27.3    1410273.0
# 9                            AL    ...            1.3       27.3    1410273.0
# 10                           AL    ...            1.3       27.3    1410273.0
# 11                           AL    ...            1.3       27.3    1410273.0
# 12                           AL    ...            1.3       27.3    1410273.0
# 13                           AL    ...            1.3       27.3    1410273.0
# 14                           AL    ...            0.0       27.0          0.0
# 15                           AL    ...            0.0       27.0          0.0
# 16                           AL    ...            0.0       27.0          0.0
# 17                           AL    ...            0.0       27.0          0.0
# 18                           AL    ...            0.0       27.0          0.0
# 19                           AL    ...            0.0       27.0          0.0
# 20                           AL    ...            0.0       27.0          0.0
# 21                           AL    ...            0.0        0.0          0.0
# 22                           AL    ...            0.0        0.0          0.0
# 23                           AL    ...            0.0        0.0          0.0
# 24                           AL    ...            0.0        0.0          0.0
# 25                           AL    ...            0.0        0.0          0.0
# 26                           AL    ...            0.0        0.0          0.0
# 27                           AL    ...            0.0        0.0          0.0
# 28                           AL    ...            0.0       23.2     341544.0
# 29                           AL    ...            0.0       23.2     341544.0
# ...                         ...    ...            ...        ...          ...
# 24978                        RI    ...            1.7       24.6    3039063.0
# 24979                        RI    ...            2.2       24.3     346092.0
# 24980                        RI    ...            9.7       28.1    6422854.0
# 24981                        RI    ...            1.0       26.0    1756988.0
# 24982                       NaN    ...            1.7       27.6   93977455.0
# 24983                       NaN    ...            0.8       22.2   13051128.0
# 24984                       NaN    ...            1.6       25.9  140447760.0
# 24985                       NaN    ...           20.7       28.2  593541502.0
# 24986                       NaN    ...            3.7       24.9   42431657.0
# 24987                       NaN    ...            0.6       26.0   10751461.0
# 24988                        VT    ...            0.0       22.1     538957.0
# 24989                        VT    ...            0.6       24.8     571644.0
# 24990                        VT    ...            0.0       28.0     339060.0
# 24991                        VT    ...            1.0       28.2    4823542.0
# 24992                        VT    ...            0.0       23.8      62793.0
# 24993                        VT    ...            0.0       23.6          0.0
# 24994                        VT    ...            0.0        0.0          0.0
# 24995                        VT    ...            0.0       31.4          0.0
# 24996                        VT    ...            0.0       24.7     161917.0
# 24997                        VT    ...            0.0       18.2          0.0
# 24998                        VT    ...            0.5       23.9     640754.0
# 24999                        VT    ...            1.0       23.0    1011871.0
# 25000                        VT    ...            0.9       30.2     375077.0
# 25001                        VT    ...            0.3       24.5     406465.0
# 25002                       NaN    ...            4.5       30.1   92417797.0
# 25003                        VA    ...            0.0       24.9          0.0
# 25004                       NaN    ...            3.2       28.7  112053283.0
# 25005                       NaN    ...            0.7       28.1   25080573.0
# 25006                       NaN    ...            1.3       25.9  163563195.0
# 25007                       NaN    ...            2.8       25.5    8834810.0
#
#          WTN220207    RTN130207  RTN131207   AFN120207  BPS030214  LND110210  \
# 0              0.0     598175.0    12003.0     88157.0      131.0     594.44
# 1              0.0     598175.0    12003.0     88157.0      131.0     594.44
# 2              0.0     598175.0    12003.0     88157.0      131.0     594.44
# 3              0.0     598175.0    12003.0     88157.0      131.0     594.44
# 4              0.0     598175.0    12003.0     88157.0      131.0     594.44
# 5              0.0     598175.0    12003.0     88157.0      131.0     594.44
# 6              0.0     598175.0    12003.0     88157.0      131.0     594.44
# 7              0.0    2966489.0    17166.0    436955.0     1384.0    1589.78
# 8              0.0    2966489.0    17166.0    436955.0     1384.0    1589.78
# 9              0.0    2966489.0    17166.0    436955.0     1384.0    1589.78
# 10             0.0    2966489.0    17166.0    436955.0     1384.0    1589.78
# 11             0.0    2966489.0    17166.0    436955.0     1384.0    1589.78
# 12             0.0    2966489.0    17166.0    436955.0     1384.0    1589.78
# 13             0.0    2966489.0    17166.0    436955.0     1384.0    1589.78
# 14             0.0     188337.0     6334.0         0.0        8.0     884.88
# 15             0.0     188337.0     6334.0         0.0        8.0     884.88
# 16             0.0     188337.0     6334.0         0.0        8.0     884.88
# 17             0.0     188337.0     6334.0         0.0        8.0     884.88
# 18             0.0     188337.0     6334.0         0.0        8.0     884.88
# 19             0.0     188337.0     6334.0         0.0        8.0     884.88
# 20             0.0     188337.0     6334.0         0.0        8.0     884.88
# 21             0.0     124707.0     5804.0     10757.0       19.0     622.58
# 22             0.0     124707.0     5804.0     10757.0       19.0     622.58
# 23             0.0     124707.0     5804.0     10757.0       19.0     622.58
# 24             0.0     124707.0     5804.0     10757.0       19.0     622.58
# 25             0.0     124707.0     5804.0     10757.0       19.0     622.58
# 26             0.0     124707.0     5804.0     10757.0       19.0     622.58
# 27             0.0     124707.0     5804.0     10757.0       19.0     622.58
# 28             0.0     319700.0     5622.0     20941.0        3.0     644.78
# 29             0.0     319700.0     5622.0     20941.0        3.0     644.78
# ...            ...          ...        ...         ...        ...        ...
# 24978    1381329.0    3242897.0    19228.0    398643.0      144.0     168.53
# 24979     263963.0    1096241.0    13483.0    343003.0      185.0     102.39
# 24980    5856937.0    5924945.0     9430.0   1065946.0      342.0     409.50
# 24981    1453151.0    1726691.0    13619.0    272795.0      251.0     329.24
# 24982   40498047.0   54298410.0    12273.0   8383463.0    27537.0   30060.70
# 24983   11400476.0   12266218.0    15390.0   1622751.0     4722.0   75811.00
# 24984   80116528.0   77547291.0    12563.0  10626759.0    27632.0   41234.90
# 24985  424238194.0  311334781.0    13061.0  42054592.0   166982.0  261231.71
# 24986   25417368.0   36574240.0    13730.0   3980570.0    17510.0   82169.62
# 24987    5121694.0    9310119.0    15005.0   1367630.0     1546.0    9216.66
# 24988     101400.0     464847.0    12657.0     48164.0      101.0     766.33
# 24989          0.0     833024.0    22861.0    106659.0       35.0     674.98
# 24990      66247.0     412719.0    13565.0     29922.0       49.0     648.86
# 24991    2392465.0    2740931.0    18188.0    360756.0      533.0     536.58
# 24992          0.0      15031.0     2325.0      3090.0        9.0     663.60
# 24993     413283.0     545346.0    11383.0     39606.0      152.0     633.71
# 24994       9066.0      39465.0     5229.0      6528.0       21.0      81.81
# 24995          0.0     313467.0    12412.0    174189.0       66.0     458.80
# 24996          0.0     237240.0     8181.0     26208.0       39.0     687.03
# 24997      73373.0     324145.0    11858.0     36307.0      200.0     693.27
# 24998     267644.0    1084887.0    17136.0    124431.0       50.0     929.82
# 24999          0.0     946580.0    16125.0    118956.0      127.0     687.23
# 25000     867141.0     660735.0    15120.0    138405.0       91.0     785.31
# 25001     327739.0     691702.0    12147.0    154409.0       73.0     969.34
# 25002   60513396.0  105663299.0    13687.0  15340483.0    28682.0   39490.09
# 25003      28870.0     124881.0    19848.0     15426.0        0.0       6.88
# 25004   76790966.0   92968519.0    14380.0  12389422.0    33898.0   66455.52
# 25005   11036467.0   20538829.0    11340.0   2553258.0     2677.0   24038.21
# 25006   59996244.0   72283321.0    12904.0   9247311.0    14622.0   54157.80
# 25007    6352890.0    8957553.0    17114.0   1469008.0     1901.0   97093.14
#
#        POP060210
# 0           91.8
# 1           91.8
# 2           91.8
# 3           91.8
# 4           91.8
# 5           91.8
# 6           91.8
# 7          114.6
# 8          114.6
# 9          114.6
# 10         114.6
# 11         114.6
# 12         114.6
# 13         114.6
# 14          31.0
# 15          31.0
# 16          31.0
# 17          31.0
# 18          31.0
# 19          31.0
# 20          31.0
# 21          36.8
# 22          36.8
# 23          36.8
# 24          36.8
# 25          36.8
# 26          36.8
# 27          36.8
# 28          88.9
# 29          88.9
# ...          ...
# 24978      985.9
# 24979      809.6
# 24980     1530.3
# 24981      385.7
# 24982      153.9
# 24983       10.7
# 24984      153.9
# 24985       96.3
# 24986       33.6
# 24987       67.9
# 24988       48.0
# 24989       55.0
# 24990       48.1
# 24991      291.7
# 24992        9.5
# 24993       75.3
# 24994       85.2
# 24995       53.3
# 24996       42.1
# 24997       39.3
# 24998       66.3
# 24999       86.6
# 25000       56.7
# 25001       58.5
# 25002      202.6
# 25003      904.6
# 25004      101.2
# 25005       77.1
# 25006      105.0
# 25007        5.8
#
# [25008 rows x 61 columns]

# %% [markdown]
# #### 실습 : 실제 데이터 전처리하기
# ---
# 군집화 실습을 위해 사용할 데이터를 미리 전처리해보자
#
# ##### 분석에 도움되는 프로그래밍 팁
# - immutable : 되도록 한번 할당된 변수를 다른 값으로 덮어쓰는 것은 피할 것
# -

# %% [markdown]
# ##### 사용 데이터 : 비누 구매 고객 데이터 (교재 21.6) - `BathSoap.xlsx`
# - sheet3 : DM_Sheet, 멤버 정보 및 비누 구입 정보
# - sheet4 : Durables, 멤버들의 비누 이외 타물품 소유 정보

# %%
# Brand 정보
brand_code_description = pd.read_csv('BathSoapBrandCode.csv')
brand_code_description

# %%
# column, Durables 정보
all_columns_description = pd.read_csv('BathSoapCodelList.csv')
all_columns_description
# Out:
#      Demographic Data                                Unnamed: 1  Unnamed: 2  \
# 0                 MEM                                 Member ID         NaN
# 1                 SEC  Socio economic class (1 = high, 4 = low)         NaN
# 2                   1                                         A         NaN
# 3                   2                                         B         NaN
# 4                   3                                         C         NaN
# 5                   4                                       D/E         NaN
# 6                 NaN                                       NaN         NaN
# 7                 FEH                        Food Eating Habits         NaN
# 8                   1                                      Pure  Vegetarian
# 9                   2                                   Veg.But       Serve
# 10                  3                                       Non  Vegetraian
# 11                  0                                       Not   Specified
# 12                NaN                                       NaN         NaN
# 13                 MT           Native Language (mother tongue)         NaN
# 14                  1                                  Assamese         NaN
# 15                  2                                   Bengali         NaN
# 16                  3                                   English         NaN
# 17                  4                                  Gujarati         NaN
# 18                  5                                     Hindi         NaN
# 19                  6                                   Kannada         NaN
# 20                  7                                  Kashmiri         NaN
# 21                  8                                   Konkani         NaN
# 22                  9                                 Malayalam         NaN
# 23                 10                                   Marathi         NaN
# 24                 11                                     Oriya         NaN
# 25                 12                                   Punjabi         NaN
# 26                 13                                Rajasthani         NaN
# 27                 14                                    Sindhi         NaN
# 28                 15                                     Tamil         NaN
# 29                 16                                    Telugu         NaN
# ..                ...                                       ...         ...
# 181                49                         Computer Printers           6
# 182                50                               Fax Machine           6
# 183                51                     Video camera/Handycam           6
# 184                52                               Radio Clock           2
# 185                53                              Deep Freezer           5
# 186                54                           Electirc Kettle           1
# 187                55                      Dish Washing Machine           5
# 188                56                              Kitchen Sink           1
# 189                57                            Floor Polisher           1
# 190                58                           Cars/Jeeps/Vans           8
# 191                59                             Auto Rickshaw           3
# 192                60                                  Tractors           5
# 193                61                       Oven-In Built Range           5
# 194                62                   Oven Ordinary Box (Gas)           3
# 195                63                        Electric Table Fan           1
# 196                64                      Electric Ceiling Fan           1
# 197                65                                     Torch           1
# 198                66                            Sewing Machine           2
# 199                67                                 Generator           5
# 200                68                       Pump Set/Water Pump           5
# 201               NaN                                       NaN         NaN
# 202               NaN                                       NaN         NaN
# 203         Not used:                                       NaN         NaN
# 204  Product Codelist                                       NaN         NaN
# 205                 2                              Toilet Soaps         NaN
# 206                 5                        Tooth Paste/Powder         NaN
# 207                 1                  Washing Soaps/Detergents         NaN
# 208                21                            Washing Powder         NaN
# 209                45                               Skin Creams         NaN
# 210                20                Edible Oils/Ghee/Vanaspati         NaN
#
#     Unnamed: 3
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9         Eggs
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# ..         ...
# 181        NaN
# 182        NaN
# 183        NaN
# 184        NaN
# 185        NaN
# 186        NaN
# 187        NaN
# 188        NaN
# 189        NaN
# 190        NaN
# 191        NaN
# 192        NaN
# 193        NaN
# 194        NaN
# 195        NaN
# 196        NaN
# 197        NaN
# 198        NaN
# 199        NaN
# 200        NaN
# 201        NaN
# 202        NaN
# 203        NaN
# 204        NaN
# 205        NaN
# 206        NaN
# 207        NaN
# 208        NaN
# 209        NaN
# 210        NaN
#
# [211 rows x 4 columns]

# %% [markdown]
# ##### pd.read_excel
# `BathSoap.xlsx` 파일에서 데이터가 있는 sheet를 DataFrame으로 변환

# %% [markdown]
# ##### pd.merge
# Durable과 Dm_Sheet을 합쳐볼 것

# %% [markdown]
# ##### 필요 없는 컬럼 삭제

# %% [markdown]
# ##### 데이터로 쓰지 못하는 열 삭제 : 결측치 처리  - pd.fillna

# %%
filled_nan_cols = ['votes', 'fraction_votes']
nan_filled_df = joined_df.copy()
nan_filled_df[filled_nan_cols] = nan_filled_df[filled_nan_cols].ffill()
nan_filled_df

# %% [markdown]
# ##### scaling
